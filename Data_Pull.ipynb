# %%
import matplotlib.pyplot as plt
from IPython.display import display
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
#import stock data from Quandl API
##change this to Alpaca if we do minute-by-minute
import quandl
quandl.ApiConfig.api_key = "tC5AjCkyqtgbMarYtnVU"

# %%
#set dates between which stock data will be pulled for a given ticker
start_pull = "2005-01-01"
end_pull = "2018-02-01"

# %%
#Adobe
adobeSymbol = "WIKI/ADBE"
adobeDf = quandl.get(adobeSymbol, start_date= start_pull, end_date= end_pull)
adobeDf
# Out:
#               Open    High       Low   Close     Volume  Ex-Dividend  \
# Date
# 2005-01-03   63.00   63.50   61.5500   61.69  2754400.0          0.0
# 2005-01-04   62.21   62.38   59.3600   60.06  3757700.0          0.0
# 2005-01-05   60.10   60.90   59.7300   59.73  1783300.0          0.0
# 2005-01-06   60.23   60.34   58.4900   58.74  3079800.0          0.0
# 2005-01-07   59.28   59.51   57.7000   58.78  4256200.0          0.0
# ...            ...     ...       ...     ...        ...          ...
# 2018-01-26  198.50  201.55  198.2500  201.30  2262478.0          0.0
# 2018-01-29  200.11  200.86  197.8700  198.23  1876216.0          0.0
# 2018-01-30  197.25  197.73  194.8900  196.90  3034232.0          0.0
# 2018-01-31  197.13  200.96  196.7500  199.76  2514574.0          0.0
# 2018-02-01  199.12  201.75  198.0845  199.38  2353675.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# Date
# 2005-01-03          1.0   31.494084   31.744037   30.769220   30.839207
# 2005-01-04          1.0   31.099158   31.184142   29.674425   30.024360
# 2005-01-05          1.0   30.044356   30.444281   29.859391   29.859391
# 2005-01-06          1.0   30.109344   30.164333   29.239507   29.364484
# 2005-01-07          1.0   29.634433   29.749411   28.844581   29.384480
# ...                 ...         ...         ...         ...         ...
# 2018-01-26          1.0  198.500000  201.550000  198.250000  201.300000
# 2018-01-29          1.0  200.110000  200.860000  197.870000  198.230000
# 2018-01-30          1.0  197.250000  197.730000  194.890000  196.900000
# 2018-01-31          1.0  197.130000  200.960000  196.750000  199.760000
# 2018-02-01          1.0  199.120000  201.750000  198.084500  199.380000
#
#             Adj. Volume
# Date
# 2005-01-03    5508800.0
# 2005-01-04    7515400.0
# 2005-01-05    3566600.0
# 2005-01-06    6159600.0
# 2005-01-07    8512400.0
# ...                 ...
# 2018-01-26    2262478.0
# 2018-01-29    1876216.0
# 2018-01-30    3034232.0
# 2018-01-31    2514574.0
# 2018-02-01    2353675.0
#
# [3292 rows x 12 columns]

# %%
plt.plot(adobeDf.index,adobeDf["Close"])
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Adobe Stock Prices")
plt.show()

# %%
#Nvdia
nvdaSymbol = "WIKI/NVDA"
nvdaDf = quandl.get(nvdaSymbol, start_date=start_pull, end_date=end_pull)
nvdaDf
# Out:
#               Open    High     Low   Close      Volume  Ex-Dividend  \
# Date
# 2005-01-03   24.38   24.72   23.48   23.58   8889300.0          0.0
# 2005-01-04   23.75   23.79   22.11   22.47   6585200.0          0.0
# 2005-01-05   22.23   22.95   22.11   22.68   6040100.0          0.0
# 2005-01-06   23.08   23.35   22.30   22.46   4696400.0          0.0
# 2005-01-07   22.51   22.68   21.70   22.03   6359100.0          0.0
# ...            ...     ...     ...     ...         ...          ...
# 2018-01-26  238.12  243.34  237.60  243.33  12755309.0          0.0
# 2018-01-29  242.74  248.11  240.61  246.85  11282948.0          0.0
# 2018-01-30  241.11  246.42  238.41  242.72  14133180.0          0.0
# 2018-01-31  245.77  249.27  244.45  245.80  11818115.0          0.0
# 2018-02-01  238.52  246.90  238.06  240.50  12716271.0          0.0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# Date
# 2005-01-03          1.0    7.540731    7.645893    7.262361    7.293291
# 2005-01-04          1.0    7.345872    7.358244    6.838621    6.949969
# 2005-01-05          1.0    6.875737    7.098433    6.838621    7.014922
# 2005-01-06          1.0    7.138642    7.222152    6.897388    6.946876
# 2005-01-07          1.0    6.962341    7.014922    6.711808    6.813877
# ...                 ...         ...         ...         ...         ...
# 2018-01-26          1.0  238.120000  243.340000  237.600000  243.330000
# 2018-01-29          1.0  242.740000  248.110000  240.610000  246.850000
# 2018-01-30          1.0  241.110000  246.420000  238.410000  242.720000
# 2018-01-31          1.0  245.770000  249.270000  244.450000  245.800000
# 2018-02-01          1.0  238.520000  246.900000  238.060000  240.500000
#
#             Adj. Volume
# Date
# 2005-01-03   26667900.0
# 2005-01-04   19755600.0
# 2005-01-05   18120300.0
# 2005-01-06   14089200.0
# 2005-01-07   19077300.0
# ...                 ...
# 2018-01-26   12755309.0
# 2018-01-29   11282948.0
# 2018-01-30   14133180.0
# 2018-01-31   11818115.0
# 2018-02-01   12716271.0
#
# [3293 rows x 12 columns]

# %%
plt.plot(nvdaDf.index,nvdaDf["Open"])
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Nvdia Stock Prices")
plt.show()

# %%
#Microsoft
msSymbol = "WIKI/MSFT"
msDf = quandl.get(msSymbol, start_date=start_pull, end_date=end_pull)
msDf
# Out:
#              Open   High      Low  Close       Volume  Ex-Dividend  \
# Date
# 2005-01-03  26.80  26.95  26.6490  26.74   65002900.0          0.0
# 2005-01-04  26.86  27.10  26.6600  26.84  109442100.0          0.0
# 2005-01-05  26.84  27.10  26.7600  26.78   72463500.0          0.0
# 2005-01-06  26.86  27.06  26.6399  26.75   76890500.0          0.0
# 2005-01-07  26.83  26.89  26.6200  26.67   68723300.0          0.0
# ...           ...    ...      ...    ...          ...          ...
# 2018-01-26  93.12  94.06  92.5800  94.06   26348999.0          0.0
# 2018-01-29  95.14  95.45  93.7200  93.92   30409620.0          0.0
# 2018-01-30  93.30  93.66  92.1000  92.74   34153798.0          0.0
# 2018-01-31  93.75  95.40  93.5100  95.01   44284284.0          0.0
# 2018-02-01  94.79  96.07  93.5813  94.26   46645657.0          0.0
#
#             Split Ratio  Adj. Open  Adj. High   Adj. Low  Adj. Close  \
# Date
# 2005-01-03          1.0  20.079805  20.192192  19.966669   20.034850
# 2005-01-04          1.0  20.124760  20.304579  19.974910   20.109775
# 2005-01-05          1.0  20.109775  20.304579  20.049835   20.064820
# 2005-01-06          1.0  20.124760  20.274609  19.959850   20.042342
# 2005-01-07          1.0  20.102282  20.147237  19.944940   19.982403
# ...                 ...        ...        ...        ...         ...
# 2018-01-26          1.0  93.120000  94.060000  92.580000   94.060000
# 2018-01-29          1.0  95.140000  95.450000  93.720000   93.920000
# 2018-01-30          1.0  93.300000  93.660000  92.100000   92.740000
# 2018-01-31          1.0  93.750000  95.400000  93.510000   95.010000
# 2018-02-01          1.0  94.790000  96.070000  93.581300   94.260000
#
#             Adj. Volume
# Date
# 2005-01-03   65002900.0
# 2005-01-04  109442100.0
# 2005-01-05   72463500.0
# 2005-01-06   76890500.0
# 2005-01-07   68723300.0
# ...                 ...
# 2018-01-26   26348999.0
# 2018-01-29   30409620.0
# 2018-01-30   34153798.0
# 2018-01-31   44284284.0
# 2018-02-01   46645657.0
#
# [3293 rows x 12 columns]

# %%
plt.plot(msDf.index,msDf["Open"])
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.title("Microsoft Stock Prices")
plt.show()

# %%
data_frames = [adobeDf, nvdaDf, msDf]

# %%
#take the date
##NOTE - not being used at the moment, but kept should we choose a specific interval
def selectInterval(startDate, endDate, dataFrame):
    selection =  (dataFrame.index >= startDate) & (dataFrame.index <= endDate)
    return dataFrame.loc[selection]


selected = selectInterval("2017-01-01","2018-01-07",adobeDf)
selected
print(len(selected))
# Out:
# 253
